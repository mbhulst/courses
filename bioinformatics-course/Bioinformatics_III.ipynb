# %%
from AA_sequencing import DNA_to_RNA
from AA_sequencing import protein_translation
from AA_sequencing import genetic_code

# %%
DNAseq_before = "..."
DNAseq_afters = "...   "

# %%
AA_before = protein_translation(DNA_to_RNA(DNAseq_before), genetic_code)

# %%
AA_after = protein_translation(DNA_to_RNA(DNAseq_afters), genetic_code)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2684/2207957139.py in <module>
# ----> 1 AA_after = protein_translation(DNA_to_RNA(DNAseq_afters), genetic_code)
#
# ~\Documents\Programming\bioinformatics-course\AA_sequencing.py in protein_translation(pattern, genetic_code)
#      19     while i < len(pattern) - 2:
#      20         codon = pattern[i:i + 3]
# ---> 21         peptide += genetic_code[codon]
#      22         i += 3
#      23     return peptide
#
# KeyError: '   '

# %%
if AA_before == AA_after:
    print(True)
else:
    print(False)
# Out:
# False
